# %%
import pandas as pd
import requests
import json
import time
import numpy as np

####
# Python request from Postman API

payload={}
headers = {
  'authority': 'storefrontgateway.saveonfoods.com',
  'accept': 'application/json, text/plain, */*',
  'accept-language': 'en-US,en;q=0.9,fr;q=0.8,es;q=0.7',
  'cookie': '__cf_bm=wjMzBNi6PxW3p8HbA._PJChcnv6T_REpq8c7frGi264-1663479712-0-AauPv/dYMV18XsPuadNC/lRr40/G3RBnbBhsDuSAlqhK2IbVKNx/dSRfwbSqDEoD5ZRtHM4NBX1zo/mVw8CyaM4tUOdekuruZX4OegOcJolvHeLGKElv0RySMZSlDMWIA1Df/mFwWHnIMUoZUSXgKYlJKNtPa9YUlBtxKBh4TuOGlJFFE6o0GBdveDqsZw+ZWQ==; _gcl_au=1.1.1520443345.1663479713; _ga=GA1.2.1922336475.1663479713; _gid=GA1.2.764078445.1663479713; _dc_gtm_UA-3016345-8=1; _gaexp=GAX1.2.2TXrwbPLRTqBNA5IC8es5w.19316.0; _fbp=fb.1.1663479713691.620429690; AMCVS_9C423E945A72D9EE0A495EF8%40AdobeOrg=1; _pin_unauth=dWlkPU5qQm1NMlJoTmpRdE56ZzRPUzAwWkRSbExUaG1NVGd0WkRoaFpESXpZVGszTWpFMg; AMCV_9C423E945A72D9EE0A495EF8%40AdobeOrg=1585540135%7CMCMID%7C26107693206724934624409335891349591500%7CMCAAMLH-1664084513%7C9%7CMCAAMB-1664084513%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCCIDH%7C-2127053844%7CMCOPTOUT-1663486913s%7CNONE%7CvVersion%7C4.4.0; _ga_ZM4WBLPQ9B=GS1.1.1663479713.1.1.1663479725.0.0.0',
  'customerid': 'unknown',
  'dnt': '1',
  'origin': 'https://www.saveonfoods.com',
  'referer': 'https://www.saveonfoods.com/',
  'sec-ch-ua': '"Google Chrome";v="105", "Not)A;Brand";v="8", "Chromium";v="105"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-site',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
  'x-correlation-id': '7984c467-d650-40de-a536-fdb2fba88de0',
  'x-shopping-mode': '11111111-1111-1111-1111-111111111111',
  'x-site-host': 'https://www.saveonfoods.com'
}

###

# define function to scrape

def save_on_scrape_api(name, skip=30):
    '''
    input the search term into Save-On-Foods API and extract data

    name: search term (e.g. meat, plant-based) in string type.
    skip: integer in the url API. Used for pagination or scrolling through the data results. default = 30
    Returns a pandas dataframe
    '''
    
    df = pd.DataFrame([]) # create blank dataframe to store data
    
    while True:
        print('Scrapping...')
        url = f"https://storefrontgateway.saveonfoods.com/api/stores/1982/search?q={name}&take=30&skip={skip}&page=1"
        r = requests.get(url, headers=headers, data=payload)
        data = json.loads(r.text)
        data_df = pd.json_normalize(data['items'], 'defaultCategory', ['productId', 'sku', 'name', 'description',
                                                    'brand', 'priceNumeric' , 'wasPriceNumeric','pricePerUnit',
                                                    ['unitOfMeasure', 'type']], errors='ignore')
        df = df.append(data_df)

        if len(data['items']) == 0:
               break

        skip += 30 # pagination increment. Allows to "scroll" through the data
        
    
        
    print('Done scrapping')
    print('Len database: ' + str(len(df)))
    
    # clean and modify dataframe
    df.rename(columns={'categoryBreadcrumb': 'categories', 'priceNumeric': 'price', 
                       'wasPriceNumeric': 'prev_price', 
                       'pricePerUnit': 'price_unit', 
                       'unitOfMeasure.type': 'unit'}, inplace=True)

    split = df.price_unit.str.split('/', expand=True)
    df['price_unit_0'] = split[0]
    df['price_unit_1'] = split[1]

    df['price_unit_0'] = df.price_unit_0.str.replace('$', '', regex=True)
    df['price_unit_0'] = df.price_unit_0.str.replace('each', '', regex=True)
    df['price_unit_1'] = df.price_unit_1.str.replace('g', '', regex=True)
    
    df.fillna(np.nan, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    return df

# %%
df = save_on_scrape_api('meat')
# Out:
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Scrapping...
# Done scrapping
# Len database: 1519

# %%
# save dataframe to csv file
df.to_csv('save-on-foods-meat-products.csv')

# %%
df.head()
# Out:
#                              categoryId retailerId           category  \
# 0  4c171bbd-ab9d-497f-ab48-9ed6eb8229db      30796    Beef Steak Cuts
# 1  9266091f-9f48-48d6-9f36-b1b69e542b0a      30808        Ground Pork
# 2  71479d85-44cf-45d5-828a-cfa548d82742      30819  Hot Dogs & Franks
# 3  4c171bbd-ab9d-497f-ab48-9ed6eb8229db      30796    Beef Steak Cuts
# 4  4c171bbd-ab9d-497f-ab48-9ed6eb8229db      30796    Beef Steak Cuts
#
#                                           categories       productId  \
# 0  Grocery/Meat & Seafood/Beef & Veal/Beef Steak ...  00236234000008
# 1      Grocery/Meat & Seafood/Pork & Ham/Ground Pork  00077782001006
# 2  Grocery/Meat & Seafood/Hot Dogs & Sausages/Hot...  00063100183943
# 3  Grocery/Meat & Seafood/Beef & Veal/Beef Steak ...  00294738000009
# 4  Grocery/Meat & Seafood/Beef & Veal/Beef Steak ...  00210410000006
#
#               sku                                               name  \
# 0  00236234000008  Western Canadian - Sirloin Tip Marinating Stea...
# 1  00077782001006  Johnsonville - Italiano Mild Italian Sausage Meat
# 2  00063100183943         Schneiders - Juicy Jumbos All Beef Wieners
# 3  00294738000009                     Western Canadian - Flank Steak
# 4  00210410000006  Western Canadian - Striploin Grilling Steak, F...
#
#                                          description             brand  \
# 0  Cut From AAA Western Canadian Beef. Aged Min. ...  Western Canadian
# 1  Gluten Free. Ground Meat Perfect Blend of Herb...      Johnsonville
# 2  Schneiders Juicy Jumbos All Beef Wieners are a...        Schneiders
# 3  AAA Beef. Grain Fed. Average Weight of Each Pa...  Western Canadian
# 4  AAA Beef. Grain Fed. Average Weight of Each Pa...  Western Canadian
#
#        price  prev_price  price_unit  unit price_unit_0 price_unit_1
# 0  18.500311         NaN  $2.20/100g  gram         2.20          100
# 1   6.990000         NaN  $1.86/100g  gram         1.86          100
# 2   8.990000         NaN  $2.40/100g  gram         2.40          100
# 3  13.709093         NaN  $3.75/100g  gram         3.75          100
# 4  27.765017         NaN  $4.63/100g  gram         4.63          100

# %% [markdown]
# ## Create Database

# %%
# save dataframe into database
from sqlalchemy import create_engine
from sqlalchemy.types import Text, Float, Integer

# open connection/create database file
engine = create_engine('sqlite:///plant-based-save-on-foods.db', echo=False)

# safe dataframe into a table in the database
df.to_sql('products', con=engine, if_exists='replace', index=False, dtype={'categoryId': Text(),
                                                                         'retailerId': Integer(),
                                                                         'category': Text(),
                                                                         'categories': Text(),
                                                                         'productId': Integer(),
                                                                         'sku': Integer(),
                                                                         'name': Text(),
                                                                         'description': Text(),
                                                                         'brand': Text(),
                                                                         'price': Float(),
                                                                         'prev_price': Float(),
                                                                          'price_unit': Text(),
                                                                          'unit': Text(),
                                                                         'price_unit_0': Float(),
                                                                         'price_unit_1': Integer()})

# %% [markdown]
# ## Query the Database

# %%
# Load the sql module to iPython
# %load_ext sql
# %sql sqlite:///plant-based-save-on-foods.db

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE retailerId = '30796';
# Out:
#  * sqlite:///plant-based-save-on-foods.db
# Done.
# [('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 236234000008, 236234000008, 'Western Canadian - Sirloin Tip Marinating Steak, Fresh Family Pack', 'Cut From AAA Western Canadian Beef. Aged Min. 14 Days, Guaranteed Tender, Fresh, Super Warehouse Pack. Grain Fed Beef. Average Weight of Each Package May Vary.', 'Western Canadian', 18.50031119350617, None, '$2.20/100g', 'gram', 2.2, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 294738000009, 294738000009, 'Western Canadian - Flank Steak', 'AAA Beef. Grain Fed. Average Weight of Each Package May Vary.', 'Western Canadian', 13.709093034347118, None, '$3.75/100g', 'gram', 3.75, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 210410000006, 210410000006, 'Western Canadian - Striploin Grilling Steak, Fresh', 'AAA Beef. Grain Fed. Average Weight of Each Package May Vary.', 'Western Canadian', 27.765017299563578, None, '$4.63/100g', 'gram', 4.63, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 297829000001, 297829000001, 'Western Canadian - Canada Prime Striploin Steak', 'This premium cut of meat is chosen from the top 2% of triple AAA cattle, for its liberal marbling, it features beautiful red meat laced with thin str ... (103 characters truncated) ...  extremely tasty eating experience. This is sure to be the talk of your next BBQ, bringing the highest quality steak available to your kitchen table.', 'Western Canadian', 28.210351069176927, None, '$7.05/100g', 'gram', 7.05, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 226477000002, 226477000002, 'Western Canadian - Top Sirloin Grilling Steak, Fresh', 'AAA Beef. Grain Fed. Average Weight of Each Package May Vary.', 'Western Canadian', 17.074802206218802, None, '$3.41/100g', 'gram', 3.41, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 260521000006, 260521000006, 'Western Canadian - Boneless Blade Simmering Steak, Fresh Family Pack', 'AAA Beef. Grain Fed. Average Weight may Vary By Pack.', 'Western Canadian', 17.783588379143154, None, '$2.09/100g', 'gram', 2.09, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 883353006352, 883353006352, 'TopGrass - Beef Striploin Steaks', 'Delicious Striploin Steaks (Frozen), perfect for the BBQ.', 'TopGrass', 16.99, None, '$6.66/100g', 'gram', 6.66, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 210348000000, 210348000000, 'Western Canadian - Canada Prime Top Sirloin Steak', 'This premium cut of meat is chosen from the top 2% of triple AAA cattle, for its liberal marbling, it features beautiful red meat laced with thin str ... (103 characters truncated) ...  extremely tasty eating experience. This is sure to be the talk of your next BBQ, bringing the highest quality steak available to your kitchen table.', 'Western Canadian', 13.109788420823737, None, '$3.75/100g', 'gram', 3.75, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 883353006345, 883353006345, 'TopGrass - Beef Rib Eye Steak', 'Delicious Rib Eye Steaks (Frozen), perfect for the BBQ.', 'TopGrass', 16.99, None, '$6.66/100g', 'gram', 6.66, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 251026000004, 251026000004, 'Western Canadian - Striploin Grilling Steak, Fresh Family Pack', 'AAA Beef. Grain Fed. Aged Min. 14 Days. Average Weight of Each Package May Vary. Approx 3 Steaks per Package.', 'Western Canadian', 29.300536955681196, 39.772494409462894, '$3.08/100g', 'gram', 3.08, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 230822000005, 230822000005, 'Western Canadian - Eye Of Round Marinating Steak, Fresh Family Pack', '4 Portions Per Package. AAA Beef Grain Fed. Random Weighted Items May Vary by Package.', 'Western Canadian', 18.50119304255492, None, '$2.31/100g', 'gram', 2.31, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 62639345570, 62639345570, 'Fast Fresh Fabulous - Noodle Bowl Kit - Yakiniku Beef', 'Great Meals Made Easy. Fresh Well Seasoned with Fresh Stir Fry Veggies & Cooked Yakisoba Noodles. Cooks in Two Minutes. For Two People. Fresh Made in Store. 760g.', 'Fast Fresh Fabulous', 12.0, None, None, 'each', None, None),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 212593000002, 212593000002, 'Western Canadian - Top Sirloin Grilling Steak, Fresh Family Pack', 'AAA Beef. Grain Fed. Average Weight of Each Package May Vary.', 'Western Canadian', 42.62637839344603, None, '$2.84/100g', 'gram', 2.84, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 254174000001, 254174000001, 'Western Canadian - Canada Prime Rib Eye Steak', 'This premium cut of meat is chosen from the top 2% of triple AAA cattle, for its liberal marbling, it features beautiful red meat laced with thin str ... (103 characters truncated) ...  extremely tasty eating experience. This is sure to be the talk of your next BBQ, bringing the highest quality steak available to your kitchen table.', 'Western Canadian', 36.58791703220227, None, '$9.15/100g', 'gram', 9.15, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 627907106798, 627907106798, 'Marcangelo - Bacon Wrapped Beef Medallions - Frozen', '6 x 4oz Marcangelo Beef Medallions. Lightly seasoned and wrapped with bacon making them the perfect mealtime go to.<br />', 'Marcangelo', 17.99, 22.99, '$2.65/100g', 'gram', 2.65, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 272503000003, 272503000003, 'Western Canadian - T Bone Grilling Steak, Fresh', 'AAA Beef. Grain Fed. Average Weight of Each Package May Vary.', 'Western Canadian', 20.779450059973517, None, '$4.52/100g', 'gram', 4.52, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 2137430000008, 2137430000008, 'Western Canadian - Tomahawk Prime Rib Steak AAA', 'The ulimate BBQ Steak! Make this unique cut of meat the center piece of your dinner table. Average weight of each package may vary.', 'Western Canadian', 52.88448745290842, None, '$4.41/100g', 'gram', 4.41, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 294745000009, 294745000009, 'Western Canadian - Sirloin Tip Marinating Steak, Family Pack', 'Cut From AAA Western Canadian Beef. Aged Min. 14 Days, Guaranteed Tender, Fresh, Super Warehouse Pack. Grain Fed Beef. Average Weight of Each Package May Vary.', 'Western Canadian', 18.50031119350617, None, '$2.20/100g', 'gram', 2.2, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 294727000003, 294727000003, 'Western Canadian - Top Sirloin Steak. Family Pack', 'AAA Beef. Grain Fed. Average Weight of Each Package May Vary.', 'Western Canadian', 39.65013785395019, None, '$2.64/100g', 'gram', 2.64, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 217557000005, 217557000005, 'Fresh - Top Sirloin Steak. Family Pack', 'AAA Beef. Grain Fed. Each Package Contains Approx 4 Pieces. Average Weight of Each Package May Vary.', 'Fresh', 39.65013785395019, None, '$2.64/100g', 'gram', 2.64, 100),
#  ('4c171bbd-ab9d-497f-ab48-9ed6eb8229db', 30796, 'Beef Steak Cuts', 'Grocery/Meat & Seafood/Beef & Veal/Beef Steak Cuts', 294723000007, 294723000007, 'Western Canadian - Striploin Steak, Family Pack', 'AAA Beef. Grain Fed. Aged Min. 14 Days. Average Weight of Each Package May Vary. Approx 3 Steaks per Package.', 'Western Canadian', 29.300536955681196, 39.772494409462894, '$3.08/100g', 'gram', 3.08, 100)]
